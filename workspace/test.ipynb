# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

N =  1000
x = np.random.randint(1, 1000, N)
y = np.random.rand(N)

plt.scatter(
    x,
    y,
)
plt.show()

import numpy
